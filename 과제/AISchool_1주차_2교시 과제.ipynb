# %% [markdown]
# # ReLU 활용하여 Perceptron 구현

# %%
import torch
import torch.nn as nn 
import numpy as np 
x_data = torch.FloatTensor([1.0,2.0])

linear = nn.Linear(2,1)
Relu = nn.LeakyReLU()
z = Relu(linear(x_data))
print(z)
# Out:
# tensor([0.6080], grad_fn=<LeakyReluBackward0>)
