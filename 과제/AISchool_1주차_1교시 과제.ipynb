# %% [markdown]
# # Homework - Calculate Loss

# %% [markdown]
# 문제
#
# |z1|z2|w11|w12|w21|w22|b1|b2|activation|
# |--|--|--|--|--|--|--|--|--|
# |0.2|0.4|0.1|0.2|0.9|0.2|0.1|0.9|softmax|

# %% [markdown]
# $ z = \begin{bmatrix}
# 0.2 & 0.4
# \end{bmatrix}$
# $ w = \begin{bmatrix}
# 0.1 & 0.9 \\
# 0.2 & 0.2
# \end{bmatrix}$
# $ b = \begin{bmatrix}
# 0.1 & 0.9
# \end{bmatrix}$
#
# a = zw + b
#
# $ a = \begin{bmatrix}
# 0.1 & 0.26
# \end{bmatrix} +
# \begin{bmatrix}
# 0.1 & 0.9
# \end{bmatrix}$
#
# $a = \begin{bmatrix}
# 0.2 & 1.16
# \end{bmatrix}$
#
# softmax(a) = [$\frac{e^{0.2}}{e^{0.2}+e^{1.16}}$,$\frac{e^{1.16}}{e^{0.2}+e^{1.16}}$]
#
# softmax(a) $\cong$ [0.2769,0.7231]

# %% [markdown]
# t  = [1.0, 0.0]
#
# - MSE loss
#
# $\frac{1}{2}${(0.28-1)^2+(0.72-0)^2}
# = 0.5184
#
# - Cross Entropy loss
#
# - (1 * log0.28 + 0 * log0.72) = 0.1426
