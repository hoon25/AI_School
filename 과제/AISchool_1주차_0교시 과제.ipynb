# %% [markdown]
# # 연습문제 - 숫자

# %% [markdown]
# - 언어 = 90, 영어 = 60, 수학 = 81
# - 위 학생의 평균 성적을 구하는 코드를 작성하세요.
# - (average)

# %%
kor = 90
eng = 60
math = 81 
average = (kor+eng+math)/3
print(average)
# Out:
# 77.0

# %% [markdown]
# # 연습문제 - 문자열

# %% [markdown]
# - Mary's cosmetics을 출력하세요.

# %%
print("Mary's cosmetics")
print('Mary\'s cosmetics')
# Out:
# Mary's cosmetics
# Mary's cosmetics

# %% [markdown]
# - "dk2jd923i1jdk2jd93jfd92"의 길이를 구하세요

# %%
len("dk2jd923i1jdk2jd93jfd92")
# Out:
# 23

# %% [markdown]
# - t1 = 'python', t2 = 'java'일 때 문자열 더하기와 곱하기를 이용하여 "python java python java python java"를 출력 하세요.

# %%
t1 = "python"
t2 = "java"
print((t1 + t2)*3) # 뛰어쓰기를 어떻게 할 지 모르겠습니다....
# Out:
# pythonjavapythonjavapythonjava

# %% [markdown]
# - id = "890910-1157963"에서 성별을 나타내는 수를 출력하세요.

# %%
id = "890910-1157963"
print(id[7])
# Out:
# 1

# %% [markdown]
# - license_plate = "24가 2210"에서 번호판 뒷자리만 출력하세요.

# %%
license_plate = "24가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %% [markdown]
# - url = portal.ac.kr 에서 kr만 출력하세요.(split 함수 사용)

# %%
url = "portal.ac.kr"
a = url.split(".")
print(a)
print(a[-1])
# Out:
# ['portal', 'ac', 'kr']
# kr

# %% [markdown]
# # 연습문제 - 리스트

# %% [markdown]
# - language1 = ["C","C++","JAVA"],language2 = ["Python","Go","C#"]두 리스트의 원소를 모두 갖는 languages를 만드세요.

# %%
language1 = ["C","C++","JAVA"]
language2 = ["Python","Go","C#"]
languages = language1 + language2
print(languages)
# Out:
# ['C', 'C++', 'JAVA', 'Python', 'Go', 'C#']

# %% [markdown]
# - nums = [12,245,33,77,858]의 평균을 구하세요

# %%
nums = [12,245,33,77,858]
print(sum(nums)/len(nums))
# Out:
# 245.0

# %% [markdown]
# - a = ["b","a","d","c"] 리스트를 알파벳 순으로 정렬하세요.

# %%
a = ["b","a","d","c"]
b = sorted(a)
print(b)

a.sort()
print(a)
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd']
